# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification,make_blobs
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
X,y = make_blobs(n_samples=500,n_features=2,centers=2,random_state=42)

# %%
X.shape
# Out:
# (500, 2)

# %%
# y
plt.scatter(X[:,0],X[:,1],c = y)
plt.show()

# %%
class SVM:
    def __init__(self,lr = 0.01):
        self.lr = lr
    def fit(self,X,y,epochs = 100):
        self.w, self.w0 = self.SVM(X,y,self.lr,epochs)

    
        
    def hypothesis(self,x,w,w0):
        return w.dot(x.T) + w0
        
    def functional_margin(self,x,w,w0,y):
        return y*self.hypothesis(x,w,w0)
        

    def loss(self,x,w,w0,y):
        ypred = self.functional_margin(x,w,w0)
        er=1-ti
        er[er<0]=0
        return 0.5*(w@w) +self.C*np.sum

    def predict(self,X):
        ypred = self.hypothesis(X,self.w,self.w0)
        ypred[ypred <=0] = 0
        ypred[ypred > 0] = 1
        return ypred

    def SVM(self,X,y,lr = 0.01,epochs = 100):
        w = np.zeros(shape=(X.shape[1],))
        w0 = 1
        self.loss_e = [self.loss(X,w,w0,y)]
        for e in range(epochs):
            ypred = self.functional_margin(X,w,w0,y)
            ti[ti<1]=-1
            ti[ti>=1]=0
            grads = w+self.C*((ti*y)@X)
            w = w - lr*grads
            w0 = w0 - lr*np.sum(self.C*((ti*y)))

            self.loss_e.append(self.loss(X,w,w0,y))
            
        return w,w0

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.2)

# %%
clf = SVM(lr = 0.001,C=1)
clf.fit(x_train,y_train,1000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 clf = SVM(lr = 0.001,C=1)
#       2 clf.fit(x_train,y_train,1000)
#
# TypeError: SVM.__init__() got an unexpected keyword argument 'C'
