# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
diabetes=pd.read_csv("diabetes.csv")

# %%
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
sns.countplot(diabetes,x="Insulin",hue="Outcome")
# Out:
# <Axes: xlabel='Insulin', ylabel='count'>

# %%
sns.kdeplot(diabetes,x="Insulin",hue="Outcome")
# Out:
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
sns.kdeplot(diabetes,x="Insulin",hue="Outcome")
# Out:
# <Axes: xlabel='Insulin', ylabel='Density'>

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
diabetes.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
sns.kdeplot(diabetes,x="DiabetesPedigreeFunction",hue="Outcome")
# Out:
# <Axes: xlabel='DiabetesPedigreeFunction', ylabel='Density'>

# %%
sns.jointplot(diabetes,x="BloodPressure",y="Pregnancies",hue="Outcome",kind="kde")

# %%
sns.countplot(diabetes,x="Glucose",hue="Outcome")
# Out:
# <Axes: xlabel='Glucose', ylabel='count'>

# %%
sns.histplot(diabetes,x="Glucose",hue="Outcome")
# Out:
# <Axes: xlabel='Glucose', ylabel='Count'>

# %%
sns.kdeplot(diabetes,x="Glucose",hue="Outcome")
# Out:
# <Axes: xlabel='Glucose', ylabel='Density'>

# %%
sns.jointplot(x="BloodPressure",y="Age",hue="Outcome",kind="kde")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 sns.jointplot(x="BloodPressure",y="Age",hue="Outcome",kind="kde")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\axisgrid.py:2243, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2240     dropna = True
#    2242 # Initialize the JointGrid object
# -> 2243 grid = JointGrid(
#    2244     data=data, x=x, y=y, hue=hue,
#    2245     palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#    2246     dropna=dropna, height=height, ratio=ratio, space=space,
#    2247     xlim=xlim, ylim=ylim, marginal_ticks=marginal_ticks,
#    2248 )
#    2250 if grid.hue is not None:
#    2251     marginal_kws.setdefault("legend", False)
#
# ...
