# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
x=pd.read_csv("xdata.csv",usecols=[1,2],index_col=False)
y=pd.read_csv("xdata.csv",usecols=[1],index_col=False)

# %%
X_data,y_data=x.values,y.values.reshape(-1)

# %%
x.shape,y.shape
# Out:
# ((399, 2), (399, 1))

# %%
plt.scatter(X_data[y(data)==0],c="red",
