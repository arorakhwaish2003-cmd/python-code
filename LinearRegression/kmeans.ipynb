# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,y=make_blobs(n_samples=500,n_features=2,centers=5,random_state=20)

# %%
plt.scatter(X[:,0],X[:,1],c=y)
plt.show()

# %%
def initialize_cluster(k=2,n_features=2,min=-10,max=10):
    clusters=[]
    for i in range(k):
        cluster={}
        cluster['center']=(max-min)*np.random.rand(n_features)+min
        cluster['points']=[]
        clusters.append(cluster)
    return clusters

# %%
clusters=initialize_cluster(5,2,np.array([-10,-5]),np.array([10,5]))

# %%
clusters
# Out:
# [{'center': array([ 5.22991198, -3.42705519]), 'points': []},
#  {'center': array([2.87803194, 4.53975335]), 'points': []},
#  {'center': array([-4.38065837, -4.90704621]), 'points': []},
#  {'center': array([-8.84800347,  1.168783  ]), 'points': []},
#  {'center': array([-8.9963426 , -4.13518257]), 'points': []}]

# %%
def distance(p1,p2):
    return np.sqrt(np.sum((p2-p1)**2))

# %%
def assign_points(X,clusters):
    for i in range(X.shape[0]):
        dist=[]
        for c in clusters:
            dist.append

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread('elephant.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (330, 500, 3)

# %%
# Flatten Each channel of the Image
all_pixels  = img.reshape((-1,3))
print(all_pixels.shape)
# Out:
# (165000, 3)

# %%
from sklearn.cluster import KMeans

# %%
dominant_colors = 4

km = KMeans(n_clusters=dominant_colors)
km.fit(all_pixels)
# Out:
# KMeans(n_clusters=4)

# %%
centers = km.cluster_centers_

# %%
centers
# Out:
# array([[188.18546101, 133.13912749,  85.73274658],
#        [ 13.67255569,  11.75422547,  23.07027716],
#        [160.74852223, 147.23063908, 150.45508867],
#        [ 76.49011571,  74.50564617, 102.51755193]])

# %%
centers = np.array(centers,dtype='uint8')

# %%
print(centers)
# Out:
# [[188 133  85]
#  [ 13  11  23]
#  [160 147 150]
#  [ 76  74 102]]

# %%
plt.figure(figsize=(centers.shape[0]*2,2))

i = 1

for center in centers:
    plt.subplot(1,centers.shape[0],i)
    i += 1
    na = np.zeros(shape=(100,100,3),dtype='uint8')
    na[:,:,:] = center
    plt.axis('off')
    plt.imshow(na)

plt.show()

# %%
new_img = np.zeros((330*500,3),dtype='uint8')

print(new_img.shape)
# Out:
# (165000, 3)

# %%
centers
# Out:
# array([[188, 133,  85],
#        [ 13,  11,  23],
#        [160, 147, 150],
#        [ 76,  74, 102]], dtype=uint8)

# %%
km.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
for ix in range(new_img.shape[0]):
    new_img[ix] = centers[km.labels_[ix]]
    
new_img = new_img.reshape((img.shape))
plt.imshow(new_img)
plt.show()
