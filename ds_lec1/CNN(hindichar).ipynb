# %%
import tensorflow as tf
from tensorflow import keras #Sequential and functional API
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.datasets import fashion_mnist
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

# %%
def import_data(path):
    data = []
    label = []
    label_encoding_name = {}
    label_encoding_num = {}
    lnum = 0
    for folder in os.listdir(path):
        label_encoding_name[folder] = lnum
        label_encoding_num[lnum] = folder
        label_path = os.path.join(path,folder)
        for imgP in os.listdir(label_path):
            img = cv2.imread(os.path.join(label_path,imgP),cv2.IMREAD_GRAYSCALE)
            data.append(img)
            label.append(lnum)
        lnum += 1
        print(folder)
    return np.array(data),np.array(label),label_encoding_name,label_encoding_num

# %%
train_data,train_label,label_encoding_name,label_encoding_num = import_data('E:/Projects/HindiCharacterRecognition/DevanagariHandwrittenCharacterDataset/Train')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 train_data,train_label,label_encoding_name,label_encoding_num = import_data('E:/Projects/HindiCharacterRecognition/DevanagariHandwrittenCharacterDataset/Train')
#
# Cell In[14], line 7, in import_data(path)
#       5 label_encoding_num = {}
#       6 lnum = 0
# ----> 7 for folder in os.listdir(path):
#       8     label_encoding_name[folder] = lnum
#       9     label_encoding_num[lnum] = folder
#
# PermissionError: [WinError 21] The device is not ready: 'E:/Projects/HindiCharacterRecognition/DevanagariHandwrittenCharacterDataset/Train'
